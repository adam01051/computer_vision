# %% [markdown]
# <a href="https://colab.research.google.com/github/adam01051/computer_vision/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install torch

# %%
import torch

# %%
print(torch.__version__)
# Out:
# 2.11.0+cu128

# %%
scalar = torch.tensor(5)
print(scalar)
# Out:
# tensor(5)

# %%
vertor = torch.tensor([1,2,3,4])
print(vertor)
# Out:
# tensor([1, 2, 3, 4])

# %%
MATRIX = torch.tensor([[1,2,3,],[4,5,6]])
print(MATRIX)
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
tensor3d = torch.stack([MATRIX,MATRIX+10])
print(tensor3d)
# Out:
# tensor([[[ 1,  2,  3],
#          [ 4,  5,  6]],
#
#         [[11, 12, 13],
#          [14, 15, 16]]])

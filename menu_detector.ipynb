# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kmader/food41")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 5.30G/5.30G [00:49<00:00, 116MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/kmader/food41/versions/5

# %%
print("hello wordl")
# Out:
# hello wordl

# %%
pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download("uzbek pilaf plov food", limit=100, output_dir="/content/pilaf_images",adult_filter_off=True,force_replace=False,timeout=60)
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.advantour.com/img/uzbekistan/culture/uzbekistan-culture-dance.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/63/a7/dd/63a7dd0f6b886e1c0e0793c6dfb8f2e5.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from http://www.advantour.com/img/uzbekistan/culture/uzbek-dance8.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://s-media-cache-ak0.pinimg.com/736x/31/52/cc/3152ccf7c7ac055787b5db5699f5f542.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://central-asia.guide/wp-content/uploads/2021/07/men_traditional_clothes_uzbek-1536x1024.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #6 from https://voicesoncentralasia.org/wp-content/uploads/2020/12/Image_2_CADC2019EmbassyPerformancePostConcert.jpeg
# [%] File Downloaded!
#
# ...

# %%
# !rm -rf /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil

source_dir = '/content/pilaf_images/uzbek pilaf plov food'
target_dir = '/content/drive/MyDrive/food101_dataset/pilaf'

os.makedirs(target_dir,exist_ok=True)

for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir,filename)
  dst_file = os.path.join(target_dir,filename)
  shutil.move(src_file,dst_file)

#

# %%
downloader.download("kebab shashlik food", limit=100, output_dir="/content/kebab_images",adult_filter_off=True,force_replace=False,timeout=60)
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.south-african-hotels.com/media/silo-hotel-cape-town.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://www.e-architect.com/wp-content/uploads/2024/08/the-silo-hotel-cape-town-zeitz-mocaa-wb.webp
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://www.voyage2africa.com/wp-content/uploads/2020/02/The-Silo-Cape-Town-views-Table-Mountain.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://the-silo-hotel.capetown-hotels-za.com/data/Photos/OriginalPhoto/15477/1547796/1547796118.JPEG
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://www.carrier.co.uk/media/3oplqck4/exterior.jpg?rxy=0.4273182957393484,0.41882483987747143&rnd=133338022890230000
# [%] File Downloaded!
#
# ...

# %%
import os, shutil

source_dir = '/content/kebab_images/kebab shashlik food'
target_dir = '/content/drive/MyDrive/food101_dataset/kebab'

os.makedirs(target_dir,exist_ok=True)

for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir,filename)
  dst_file = os.path.join(target_dir,filename)
  shutil.move(src_file,dst_file)

#

# %%
downloader.download("pizza",
                    limit=100,
                    output_dir="/content/pizza_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60)
# Out:
# [%] Downloading Images to /content/pizza_images/pizza
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 65 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn.britannica.com/08/177308-050-94D9D6BE/Food-Pizza-Basil-Tomato.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://supercurioso.com/wp-content/uploads/2023/04/persona-recibiendo-un-pedazo-de-pizza-de-pepperoni-con-queso.jpg_s1024x1024wisk20cokpgZ7WhSGy-697KHu_dT5N8dfYatJ7VWHouPzGmGBs.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://img.freepik.com/premium-photo/closeup-pepperoni-pizza-slice-with-cheese-pull-highlighting-stringy-mozzarella_198067-337972.jpg?w=1380
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://wallpapers.com/images/hd/pizza-pictures-bdwo87aqbqoaj5sj.jpg
# [%] File Downloaded!
#
# ...

# %%
import os, shutil

source_dir = '/content/pizza_images/pizza'
target_dir = '/content/drive/MyDrive/food101_dataset/pizza'

os.makedirs(target_dir,exist_ok=True)

for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir,filename)
  dst_file = os.path.join(target_dir,filename)
  shutil.move(src_file,dst_file)

#

# %%
downloader.download("chocolate_cake",
                    limit=100,
                    output_dir="/content/chocolate_cake_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60)
# Out:
# [%] Downloading Images to /content/chocolate_cake_images/chocolate_cake
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 50 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://lilluna.com/wp-content/uploads/2019/01/Chocolate-Cake103.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://thenovicechefblog.com/wp-content/uploads/2020/05/Best-Chocolate-Cake-Recipe-7.jpeg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://chelsweets.com/wp-content/uploads/2021/10/death-by-chocolate-cake-cut-open-vert-edited-scaled.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://richanddelish.com/wp-content/uploads/2023/04/Matildas-Chocolate-Cake.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://www.piesandtacos.com/wp-content/uploads/2024/04/chocolate-birthday-cake-scaled.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #6 from https://www.cookingclassy.com/wp-content/uploads/2019/10/chocolate-cake-3.jpg
# [%] File Downloaded!
# ...

# %%
import os, shutil

source_dir = '/content/chocolate_cake_images/chocolate_cake'
target_dir = '/content/drive/MyDrive/food101_dataset/chocolate_cake'

os.makedirs(target_dir,exist_ok=True)

for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir,filename)
  dst_file = os.path.join(target_dir,filename)
  shutil.move(src_file,dst_file)

#

# %%
downloader.download("cheesecake",
                    limit=100,
                    output_dir="/content/cheesecake_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60)
# Out:
# [%] Downloading Images to /content/cheesecake_images/cheesecake
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://images.stockcake.com/public/b/c/b/bcbb1d20-acb1-432d-a005-e025be505cd3_large/elegant-vintage-interior-stockcake.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://i.pinimg.com/736x/5f/cb/ed/5fcbedf460595a94cd5b50631ba5f6c6.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from http://bitangra.com/blog/wp-content/uploads/2015/11/The-5-Rules-of-Vintage-Interior-Design-bitangra-furniture-10.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://designbx.com/wp-content/uploads/2017/11/Vintage-red-velvet-couch.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://i.pinimg.com/originals/51/3c/15/513c15cba9b22769b96c72c4bc5a6faa.jpg
# [%] File Downloaded!
#
# ...

# %%
import os, shutil

source_dir = '/content/cheesecake_images/cheesecake'
target_dir = '/content/drive/MyDrive/food101_dataset/cheesecake'

os.makedirs(target_dir,exist_ok=True)

for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir,filename)
  dst_file = os.path.join(target_dir,filename)
  shutil.move(src_file,dst_file)

#

# %%
downloader.download("hot_dog",
                    limit=100,
                    output_dir="/content/hot_dog_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60)
# Out:
# [%] Downloading Images to /content/hot_dog_images/hot_dog
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 73 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://potatorolls.com/wp-content/uploads/2020/10/Basic-Hot-Dogs.jpg
# [!] Issue getting: https://potatorolls.com/wp-content/uploads/2020/10/Basic-Hot-Dogs.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from https://thewoodenskillet.com/wp-content/uploads/2022/04/air-fryer-hot-dog-recipe-1.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://www.myforkinglife.com/wp-content/uploads/2023/03/oven-baked-hot-dogs-10686.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://img.freepik.com/premium-photo/hot-dog-with-onions-mustard-it_899870-9422.jpg?w=2000
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/84/57/3c/84573c6036c161e5e0178ec5016a9cee.jpg
# [%] File Downloaded!
#
# ...

# %%
import os, shutil

source_dir = '/content/hot_dog_images/hot_dog'
target_dir = '/content/drive/MyDrive/food101_dataset/hot_dog'

os.makedirs(target_dir,exist_ok=True)

for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir,filename)
  dst_file = os.path.join(target_dir,filename)
  shutil.move(src_file,dst_file)

#

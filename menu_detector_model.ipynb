# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_PATH = '/content/MyDrive/food101_dataset'
print(DATASET_PATH)


CUSTOM_CLASS_MAPPING = {'hamburger':'hamburger',
                        'hot_dog':'hot_dog',
                        'chocolate_cake':'chocolate_cake',
                        'cheesecake':'cheesecake',
                        'desert':'desert',
                        'kebab':'kebab',
                        'pilaf':'pilaf'
                        }
# Out:
# /content/MyDrive/food101_dataset

# %%
CLASSES = ['hamburger','hot_dog','desert','chocolate_cake','kebab','pilaf']
CLASS_TO_IDX = {cls: i for i, cls in enumerate(CLASSES)}
NUM_CLASSES =len(CLASSES)
print(CLASS_TO_IDX)
# Out:
# {'hamburger': 0, 'hot_dog': 1, 'desert': 2, 'kebab': 3, 'pilaf': 4}
